# %%
# !pip install --upgrade numpy pandas
# Out:
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.9 kB 131.3 kB/s eta 0:00:01
#      ------------ ------------------------- 20.5/60.9 kB 131.3 kB/s eta 0:00:01
#      ------------ ------------------------- 20.5/60.9 kB 131.3 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/60.9 kB 109.5 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/60.9 kB 109.5 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.9 kB 103.8 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/60.9 kB 114.1 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/60.9 kB 114.1 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 111.8 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
# ...

# %%
# !pip install --upgrade seaborn

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
from ydata_profiling import ProfileReport

# %%
df=pd.read_csv('Popular_Baby_Names_cleaned.csv')
df.head()
# Out:
#    Year of Birth  Gender Ethnicity Child's First Name  Count  Rank
# 0           2011  FEMALE  HISPANIC          GERALDINE     13    75
# 1           2011  FEMALE  HISPANIC                GIA     21    67
# 2           2011  FEMALE  HISPANIC             GIANNA     49    42
# 3           2011  FEMALE  HISPANIC            GISELLE     38    51
# 4           2011  FEMALE  HISPANIC              GRACE     36    53
